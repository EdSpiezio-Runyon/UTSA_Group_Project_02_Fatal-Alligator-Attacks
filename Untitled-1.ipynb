# %% [markdown]
# # SQL Load Project 2

# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Store CSV into DataFrame

# %%
csv_file = "API_weather.csv"
API_weather_df = pd.read_csv(csv_file)
API_weather_df.head()
# Out:
#      Lat    Lng        Date  Max Temp (F)  Rain (mm)
# 0  32.25 -80.75  2022-08-15          86.4        0.0
# 1  27.00 -82.25  2022-07-15          90.3        0.8
# 2  33.75 -79.00  2022-06-24          83.8        0.0
# 3  28.00 -82.75  2022-05-31          83.0        1.0
# 4  30.25 -89.75  2021-08-30          82.6       72.6

# %% [markdown]
# ### Store Second CSV into Dataframe

# %%
alligator_file = "fatal_alligator_attacks_US_with_latlng.csv"
alligator_df = pd.read_csv(alligator_file)
alligator_df.head()
# Out:
#          Date  UNIX_start_date  UNIX_end_date  First Name   Last Name Age  \
# 0  2022-08-15     1.660522e+09   1.660522e+09      Nancy       Becker  88
# 1  2022-07-15     1.657843e+09   1.657843e+09  Rose Marie     Wiegand  81
# 2  2022-06-24     1.656029e+09   1.656029e+09    Micheal     Burstein  75
# 3  2022-05-31     1.653955e+09   1.653955e+09       Sean   McGuinness  47
# 4  2021-08-30     1.630282e+09   1.630282e+09    Timothy    Satterlee  71
#
#       Sex                City           State    Lat    Lng  \
# 0  female  Hilton Head Island  South Carolina  32.22 -80.75
# 1  female           Englewood         Florida  26.96 -82.35
# 2    male        Myrtle Beach  South Carolina  33.69 -78.89
# 3    male               Largo         Florida  27.91 -82.79
# 4    male             Slidell       Louisiana  30.28 -89.78
#
#                                              Details
# 0  The victim fell into a pond in a gated communi...
# ...

# %% [markdown]
# ### Create new data with select columns

# %%
new_alligator_df = alligator_df[['Date', 'First Name', 'Last Name', 'Age', 'Sex', 'City', 'State', 'Lat', 'Lng', 'Details' ]].copy()
new_alligator_df.head()
# Out:
#          Date  First Name   Last Name Age     Sex                City  \
# 0  2022-08-15      Nancy       Becker  88  female  Hilton Head Island
# 1  2022-07-15  Rose Marie     Wiegand  81  female           Englewood
# 2  2022-06-24    Micheal     Burstein  75    male        Myrtle Beach
# 3  2022-05-31       Sean   McGuinness  47    male               Largo
# 4  2021-08-30    Timothy    Satterlee  71    male             Slidell
#
#             State    Lat    Lng  \
# 0  South Carolina  32.22 -80.75
# 1         Florida  26.96 -82.35
# 2  South Carolina  33.69 -78.89
# 3         Florida  27.91 -82.79
# 4       Louisiana  30.28 -89.78
#
#                                              Details
# 0  The victim fell into a pond in a gated communi...
# 1  The victim fell into a pond along a golf cours...
# 2  The victim was dragged into a pond in Myrtle B...
# 3  The victim was attacked while trying to retrie...
# 4  The victim was attacked in floodwaters of Hurr...

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'postgres'
host = 'localhost'
port = 5432
database_name = 'fatal_gator_db'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 9 in <cell line: 8>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=5'>6</a> database_name = 'fatal_gator_db'
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=6'>7</a> rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X13sdW50aXRsZWQ%3D?line=7'>8</a> engine = create_engine(rds_connection_string)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
# ...
